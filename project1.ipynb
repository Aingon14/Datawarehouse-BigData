# %% [markdown]
# <a href="https://colab.research.google.com/github/Aingon14/Datawarehouse-BigData/blob/main/project1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Member
# - นางสาวรัตชฎากร นามวงศ์                643020517-1
# - นางสาวชนม์ชนก อังคุระษี                643021263-1
# - นางสาวธิติพร หิงพุดซา 643021267-3
# - นางสาวศดานันท์ ทรัพย์มีมหาศาล  643021272-0
# - นางสาวสุนิสา อุดมขันธุ์ 643021278-8
# - นางสาวอิงอร พลพาล 643021279-6

# %%
import numpy as np
import pandas as pd
import os

# %%
from google.colab import drive # เชื่อมบัญชีกับ google drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.chdir('/content/drive/MyDrive/DataViz23Data/3/Data-Viz-2023-2')

! pwd  #เช็ค path ที่กำลังทำงานอยู่  เครื่องหมาย ! เพราะอยู่ในโน๊ตบุ๊ค
# Out:
# /content/drive/.shortcut-targets-by-id/12P345W-7yfEVWYLBQrbu5kvt7JHLEhMU/Data-Viz-2023-2

# %%
import pandas as pd

ectreport = 'ectreport66.xlsx'   #ชื่อไฟล์ xlxs
dfs = pd.ExcelFile('/content/drive/MyDrive/DataViz23Data/ectreport66.xlsx' )  #คำสั่งอ่านไฟล์ xlsx

dfs.sheet_names  #คำสั่งเช็คว่าในไฟล์ มี sheet ย่อยชื่อว่าอะไรบ้าง
# Out:
# ['Schema',
#  'result_constituencies_PartyList',
#  'result_constituencies_Candidate',
#  'result_constituencies_status',
#  'info_province',
#  'info_party_overview',
#  'info_constituency',
#  'Candidate_Constituency',
#  'Candidate_PartyList',
#  'Candidate_PM']

# %% [markdown]
# # ข้อมูลที่เราต้องการใน Dashboard
#
# *   จำนวนผู้มีสิทธิ์เลือกตั้งทั้งหมดทั่วประเทศ
# *   จำนวนผู้มาใช้สิทธิ์เลือกตั้งทั้งหมดทั่วประเทศ
# *   จำนวนคะแนนเลือกตั้งของพรรคทั้งหมด ของจังหวัดเชียงใหม่
# *   จำนวนผู้มาใช้สิทธิ์เลือกตั้งทั้งหมดของจังหวัดเชียงใหม่
# *    คะแนนเสียงในจังหวัดเชียงใหม่คิดเป็นร้อยละของผู้ที่มาใช้สิทธิเลือกตั้ง
# *   รายชื่อ ส.ส. แบ่งเขตที่ได้คะแนนเสียงมากมากที่สุด 10 อันดับแรกของจังหวัดเชียงใหม่
# *   คะแนนเสียงของพรรคที่มีมากที่สุด 10 อันดับแรกในจังหวัดเชียงใหม่

# %%
# select sheet page by sheet name
Schema = dfs.parse('Schema')
result_constituencies_PartyList = dfs.parse('result_constituencies_PartyList')
result_constituencies_Candidate = dfs.parse('result_constituencies_Candidate')
result_constituencies_status = dfs.parse('result_constituencies_status')
info_province = dfs.parse('info_province')
info_party_overview = dfs.parse('info_party_overview')
info_constituency = dfs.parse('info_constituency')
Candidate_constituency = dfs.parse('Candidate_Constituency')
Candidate_partyList = dfs.parse('Candidate_PartyList')
Candidate_pm = dfs.parse('Candidate_PM')

# %%
print(info_constituency.isnull().any()) # เช็คค่าว่าง Null .any คือแต่ละคอลัมน์
info_constituency.head()
# Out:
# cons_id                False
# cons_no                False
# prov_id                False
# registered_vote        False
# total_vote_stations    False
# zone                    True
# dtype: bool
#   cons_id  cons_no prov_id  registered_vote  total_vote_stations  \
# 0   ACR_1        1     ACR           145416                  310
# 1   ACR_1        1     ACR           145416                  310
# 2   ACR_2        2     ACR           155938                  331
# 3   ACR_2        2     ACR           155938                  331
# 4   ACR_2        2     ACR           155938                  331
#
#                    zone
# 0  อำเภอเมืองอำนาจเจริญ
# 1         อำเภอหัวตะพาน
# 2       อำเภอเสนางคนิคม
# 3          อำเภอชานุมาน
# 4      อำเภอปทุมราชวงศา

# %%
info_constituency[info_constituency['zone'].isnull()]  #ดูว่า row ไหนที่มีค่า null
# Out:
#      cons_id  cons_no prov_id  registered_vote  total_vote_stations zone
# 804    RNG_1        1     RNG           140024                  209  NaN
# 817    SBR_1        1     SBR           168055                  213  NaN
# 839    SKM_1        1     SKM           156558                  257  NaN
# 1037   TRT_1        1     TRT           175112                  314  NaN

# %%
import numpy as np
# แทนค่าว่าง
info_constituency['zone'] = np.where(info_constituency['prov_id'] == 'RNG', 'อำเภอเมืองระนอง', info_constituency['zone'])
info_constituency['zone'] = np.where(info_constituency['prov_id'] == 'SBR', 'อำเภอเมืองสิงห์บุรี', info_constituency['zone'])
info_constituency['zone'] = np.where(info_constituency['prov_id'] == 'SKM', 'อำเภอเมืองสมุทรสงคราม', info_constituency['zone'])
info_constituency['zone'] = np.where(info_constituency['prov_id'] == 'TRT', 'อำเภอเมืองตราด', info_constituency['zone'])
info_constituency.head()
# Out:
#   cons_id  cons_no prov_id  registered_vote  total_vote_stations  \
# 0   ACR_1        1     ACR           145416                  310
# 1   ACR_1        1     ACR           145416                  310
# 2   ACR_2        2     ACR           155938                  331
# 3   ACR_2        2     ACR           155938                  331
# 4   ACR_2        2     ACR           155938                  331
#
#                    zone
# 0  อำเภอเมืองอำนาจเจริญ
# 1         อำเภอหัวตะพาน
# 2       อำเภอเสนางคนิคม
# 3          อำเภอชานุมาน
# 4      อำเภอปทุมราชวงศา

# %%
info_constituency[info_constituency['zone'].isnull()]   # เช็คดูว่ายังมีค่า null มั้ย
# Out:
# Empty DataFrame
# Columns: [cons_id, cons_no, prov_id, registered_vote, total_vote_stations, zone]
# Index: []

# %%
#จำนวนผู้มีสิทธิเลือกตั้งทั่วประเทศ
info_constituency['registered_vote'].sum()
# Out:
# 148739554

# %%
#จำนวนผู้มาใช้สิทธิ์ทั้งหมด
result_constituencies_status['turn_out'].sum()
# Out:
# 39284752

# %%
#info_province['eng']
# Out:
# 0                AMNAT CHAROEN
# 1                    ANG THONG
# 2     PHRA NAKHON SI AYUTTHAYA
# 3                      BANGKOK
# 4                    BUENG KAN
#                 ...
# 72                  UDON THANI
# 73                 UTHAI THANI
# 74                   UTTARADIT
# 75                        YALA
# 76                    YASOTHON
# Name: eng, Length: 77, dtype: object

# %%
#cm_table = info_province[info_province['eng'] == 'CHIANG MAI']
#cm_table
# Out:
#    province_id prov_id   province         eng abbre_thai  \
# 8           50     CMI  เชียงใหม่  CHIANG MAI         ชม
#
#    total_registered_vote  total_vote_stations
# 8                1331007                 2615

# %%
result_constituencies_Candidate

# %%
result_constituencies_PartyList

# %%
data_table_cm = result_constituencies_Candidate.merge(info_province, how ='left', left_on='mp_app_id',right_on='province')
print(data_table_cm.shape)
data_table_cm.head()
# Out:
# (4781, 13)
#   cons_id mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  party_id  \
# 0   ACR_1   ACR_1_1            9          459              0.43477       706
# 1   ACR_1  ACR_1_10            1        38275             36.25419       709
# 2   ACR_1  ACR_1_11           13          126              0.11935       712
# 3   ACR_1  ACR_1_12           12          127              0.12029       742
# 4   ACR_1  ACR_1_13           11          212              0.20081       761
#
#    province_id prov_id province  eng abbre_thai  total_registered_vote  \
# 0          NaN     NaN      NaN  NaN        NaN                    NaN
# 1          NaN     NaN      NaN  NaN        NaN                    NaN
# 2          NaN     NaN      NaN  NaN        NaN                    NaN
# 3          NaN     NaN      NaN  NaN        NaN                    NaN
# 4          NaN     NaN      NaN  NaN        NaN                    NaN
#
#    total_vote_stations
# 0                  NaN
# ...

# %%
info_party_overview
# Out:
#      id  party_no           name    abbr    color  \
# 0   701      26.0   ประชาธิปัตย์    ปชป.  #06aff3
# 1   702      63.0     ประชากรไทย    ปชท.  #0f41ce
# 2   703      60.0   ความหวังใหม่    ควม.  #e6b750
# 3   705      29.0       เพื่อไทย     พท.  #da3731
# 4   706      14.0  ชาติพัฒนากล้า    ชพก.  #233e8a
# ..  ...       ...            ...     ...      ...
# 65  780      55.0    ไทยก้าวหน้า    ทกน.  #b9bee3
# 66  781       9.0           พลัง      พ.  #8e8fc7
# 67  783      52.0  ชาติรุ่งเรือง    ชรร.  #9cb4c9
# 68  784      23.0       รวมใจไทย  ร.จ.ท.  #eec49a
# 69  786      20.0        เปลี่ยน      ป.  #cc898a
#
#                                              logo_url
# 0   https://cdn.ectreport.com/images/logos/ประชาธิ...
# 1   https://cdn.ectreport.com/images/logos/ประชากร...
# 2   https://cdn.ectreport.com/images/logos/ความหวั...
# 3   https://cdn.ectreport.com/images/logos/เพื่อไท...
# 4   https://cdn.ectreport.com/images/logos/ชาติพัฒ...
# ...

# %%
info_province
# Out:
#     province_id prov_id         province                       eng abbre_thai  \
# 0            37     ACR       อำนาจเจริญ             AMNAT CHAROEN         อจ
# 1            15     ATG          อ่างทอง                 ANG THONG         อท
# 2            14     AYA  พระนครศรีอยุธยา  PHRA NAKHON SI AYUTTHAYA         อย
# 3            10     BKK    กรุงเทพมหานคร                   BANGKOK        กทม
# 4            38     BKN           บึงกาฬ                 BUENG KAN         บก
# ..          ...     ...              ...                       ...        ...
# 72           41     UDN         อุดรธานี                UDON THANI         อด
# 73           61     UTI        อุทัยธานี               UTHAI THANI         อน
# 74           53     UTT        อุตรดิตถ์                 UTTARADIT         อต
# 75           95     YLA             ยะลา                      YALA         ยล
# 76           35     YST            ยโสธร                  YASOTHON         ยส
#
# ...

# %%
#data_table_cm = result_constituencies_PartyList.merge(cm_table, how ='left', left_on='party_id',right_on='province_id')
#print(data_table_cm.shape)
#data_table_cm.head()
# Out:
# (26800, 11)
#   cons_id  party_id  party_list_vote  party_list_vote_percent  province_id  \
# 0   ACR_1       701             4550                  4.30977          NaN
# 1   ACR_1       702              185                  0.17523          NaN
# 2   ACR_1       703               67                  0.06346          NaN
# 3   ACR_1       705            33576                 31.80328          NaN
# 4   ACR_1       706              132                  0.12503          NaN
#
#   prov_id province  eng abbre_thai  total_registered_vote  total_vote_stations
# 0     NaN      NaN  NaN        NaN                    NaN                  NaN
# 1     NaN      NaN  NaN        NaN                    NaN                  NaN
# 2     NaN      NaN  NaN        NaN                    NaN                  NaN
# 3     NaN      NaN  NaN        NaN                    NaN                  NaN
# 4     NaN      NaN  NaN        NaN                    NaN                  NaN

# %%
data_table_cm = result_constituencies_PartyList.merge(info_province, how ='left', left_on='party_id',right_on='province_id')
print(data_table_cm.shape)
data_table_cm.head()
# Out:
# (26800, 11)
#   cons_id  party_id  party_list_vote  party_list_vote_percent  province_id  \
# 0   ACR_1       701             4550                  4.30977          NaN
# 1   ACR_1       702              185                  0.17523          NaN
# 2   ACR_1       703               67                  0.06346          NaN
# 3   ACR_1       705            33576                 31.80328          NaN
# 4   ACR_1       706              132                  0.12503          NaN
#
#   prov_id province  eng abbre_thai  total_registered_vote  total_vote_stations
# 0     NaN      NaN  NaN        NaN                    NaN                  NaN
# 1     NaN      NaN  NaN        NaN                    NaN                  NaN
# 2     NaN      NaN  NaN        NaN                    NaN                  NaN
# 3     NaN      NaN  NaN        NaN                    NaN                  NaN
# 4     NaN      NaN  NaN        NaN                    NaN                  NaN

# %%
data_table_cm[data_table_cm.isnull()]
# Out:
#       cons_id  party_id  party_list_vote  party_list_vote_percent  \
# 0         NaN       NaN              NaN                      NaN
# 1         NaN       NaN              NaN                      NaN
# 2         NaN       NaN              NaN                      NaN
# 3         NaN       NaN              NaN                      NaN
# 4         NaN       NaN              NaN                      NaN
# ...       ...       ...              ...                      ...
# 26795     NaN       NaN              NaN                      NaN
# 26796     NaN       NaN              NaN                      NaN
# 26797     NaN       NaN              NaN                      NaN
# 26798     NaN       NaN              NaN                      NaN
# 26799     NaN       NaN              NaN                      NaN
#
#        province_id prov_id province  eng abbre_thai  total_registered_vote  \
# 0              NaN     NaN      NaN  NaN        NaN                    NaN
# ...

# %%
#table_cm_new = data_table_cm.merge(info_party_overview, how ='left', left_on='province_id',right_on='id')
#print(table_cm_new.shape)
#table_cm_new.head()
# Out:
# (1, 19)
#    province_id prov_id   province         eng abbre_thai  \
# 0           50     CMI  เชียงใหม่  CHIANG MAI         ชม
#
#    total_registered_vote  total_vote_stations cons_id mp_app_id  mp_app_rank  \
# 0                1331007                 2615     NaN       NaN          NaN
#
#    mp_app_vote  mp_app_vote_percent  party_id  id  party_no name abbr color  \
# 0          NaN                  NaN       NaN NaN       NaN  NaN  NaN   NaN
#
#   logo_url
# 0      NaN

# %% [markdown]
# # 1. ในแต่ละจังหวัด ส.ส.แบ่งเขต พรรคใดมีคะแนนเสียงมากที่สุด

# %%
# คะแนนเสียงส.ส.เขต
result_constituencies_Candidate.head()
# Out:
#   cons_id mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  party_id
# 0   ACR_1   ACR_1_1            9          459              0.43477       706
# 1   ACR_1  ACR_1_10            1        38275             36.25419       709
# 2   ACR_1  ACR_1_11           13          126              0.11935       712
# 3   ACR_1  ACR_1_12           12          127              0.12029       742
# 4   ACR_1  ACR_1_13           11          212              0.20081       761

# %%
# ผู้สมัครส.ส.
Candidate_constituency.head()
# Out:
#   mp_app_id             mp_app_name  mp_app_no  mp_app_party_id  \
# 0   ACR_1_1   นางสาวปิยะมาศ บัวแก้ว          1              706
# 1  ACR_1_10  นางสุขสมรวย วันทนียกุล         10              709
# 2  ACR_1_11     นายการันต์ ลุนพันธ์         11              712
# 3  ACR_1_12          นายไสว ผลาวงศ์         12              742
# 4  ACR_1_13        นายสงบ โสภิพันธ์         13              761
#
#                                            image_url
# 0  https://cdn.ectreport.com/images/mp_candidates...
# 1  https://cdn.ectreport.com/images/mp_candidates...
# 2  https://cdn.ectreport.com/images/mp_candidates...
# 3  https://cdn.ectreport.com/images/mp_candidates...
# 4  https://cdn.ectreport.com/images/mp_candidates...

# %%
# ชื่อพรรคที่สังกัด
info_party_overview.head()
# Out:
#     id  party_no           name  abbr    color  \
# 0  701      26.0   ประชาธิปัตย์  ปชป.  #06aff3
# 1  702      63.0     ประชากรไทย  ปชท.  #0f41ce
# 2  703      60.0   ความหวังใหม่  ควม.  #e6b750
# 3  705      29.0       เพื่อไทย   พท.  #da3731
# 4  706      14.0  ชาติพัฒนากล้า  ชพก.  #233e8a
#
#                                             logo_url
# 0  https://cdn.ectreport.com/images/logos/ประชาธิ...
# 1  https://cdn.ectreport.com/images/logos/ประชากร...
# 2  https://cdn.ectreport.com/images/logos/ความหวั...
# 3  https://cdn.ectreport.com/images/logos/เพื่อไท...
# 4  https://cdn.ectreport.com/images/logos/ชาติพัฒ...

# %%
# merge คะแนนเสียงส.ส.เขต x ผู้สมัครส.ส.
data_table_merge1 = result_constituencies_Candidate.merge(Candidate_constituency, how ='left', left_on='mp_app_id',right_on='mp_app_id')
print(data_table_merge1.shape)
data_table_merge1.head()
# Out:
# (4781, 10)
#   cons_id mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  party_id  \
# 0   ACR_1   ACR_1_1            9          459              0.43477       706
# 1   ACR_1  ACR_1_10            1        38275             36.25419       709
# 2   ACR_1  ACR_1_11           13          126              0.11935       712
# 3   ACR_1  ACR_1_12           12          127              0.12029       742
# 4   ACR_1  ACR_1_13           11          212              0.20081       761
#
#               mp_app_name  mp_app_no  mp_app_party_id  \
# 0   นางสาวปิยะมาศ บัวแก้ว          1              706
# 1  นางสุขสมรวย วันทนียกุล         10              709
# 2     นายการันต์ ลุนพันธ์         11              712
# 3          นายไสว ผลาวงศ์         12              742
# 4        นายสงบ โสภิพันธ์         13              761
#
#                                            image_url
# 0  https://cdn.ectreport.com/images/mp_candidates...
# 1  https://cdn.ectreport.com/images/mp_candidates...
# ...

# %%
# merge คะแนนเสียงส.ส.เขต x ผู้สมัครส.ส. x ชื่อพรรคที่สังกัด
data_table_merge2 = data_table_merge1.merge(info_party_overview, how ='left', left_on='party_id',right_on='id')
print(data_table_merge2.shape)
data_table_merge2.head()
# Out:
# (4781, 16)
#   cons_id mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  party_id  \
# 0   ACR_1   ACR_1_1            9          459              0.43477       706
# 1   ACR_1  ACR_1_10            1        38275             36.25419       709
# 2   ACR_1  ACR_1_11           13          126              0.11935       712
# 3   ACR_1  ACR_1_12           12          127              0.12029       742
# 4   ACR_1  ACR_1_13           11          212              0.20081       761
#
#               mp_app_name  mp_app_no  mp_app_party_id  \
# 0   นางสาวปิยะมาศ บัวแก้ว          1              706
# 1  นางสุขสมรวย วันทนียกุล         10              709
# 2     นายการันต์ ลุนพันธ์         11              712
# 3          นายไสว ผลาวงศ์         12              742
# 4        นายสงบ โสภิพันธ์         13              761
#
#                                            image_url   id  party_no  \
# 0  https://cdn.ectreport.com/images/mp_candidates...  706      14.0
# ...

# %%
# merge คะแนนเสียงส.ส.เขต x ผู้สมัครส.ส. x ชื่อพรรคที่สังกัด x จำนวนผู้มาใช้สิทธิ์
data_table_merge3 = data_table_merge2.merge(result_constituencies_status, how ='left', left_on='cons_id',right_on='cons_id')
print(data_table_merge3.shape)
data_table_merge3.head()
# Out:
# (4781, 22)
#   cons_id mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  party_id  \
# 0   ACR_1   ACR_1_1            9          459              0.43477       706
# 1   ACR_1  ACR_1_10            1        38275             36.25419       709
# 2   ACR_1  ACR_1_11           13          126              0.11935       712
# 3   ACR_1  ACR_1_12           12          127              0.12029       742
# 4   ACR_1  ACR_1_13           11          212              0.20081       761
#
#               mp_app_name  mp_app_no  mp_app_party_id  \
# 0   นางสาวปิยะมาศ บัวแก้ว          1              706
# 1  นางสุขสมรวย วันทนียกุล         10              709
# 2     นายการันต์ ลุนพันธ์         11              712
# 3          นายไสว ผลาวงศ์         12              742
# 4        นายสงบ โสภิพันธ์         13              761
#
#                                            image_url  ...             name  \
# 0  https://cdn.ectreport.com/images/mp_candidates...  ...    ชาติพัฒนากล้า
# ...

# %%
# merge คะแนนเสียงส.ส.เขต x ผู้สมัครส.ส. x ชื่อพรรคที่สังกัด x จำนวนผู้มาใช้สิทธิ์ x จังหวัด
data_table_merge4 = data_table_merge3.merge(info_province, how ='left', left_on='prov_id',right_on='prov_id')
print(data_table_merge4 .shape)
data_table_merge4 .head()
# Out:
# (4781, 28)
#   cons_id mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  party_id  \
# 0   ACR_1   ACR_1_1            9          459              0.43477       706
# 1   ACR_1  ACR_1_10            1        38275             36.25419       709
# 2   ACR_1  ACR_1_11           13          126              0.11935       712
# 3   ACR_1  ACR_1_12           12          127              0.12029       742
# 4   ACR_1  ACR_1_13           11          212              0.20081       761
#
#               mp_app_name  mp_app_no  mp_app_party_id  \
# 0   นางสาวปิยะมาศ บัวแก้ว          1              706
# 1  นางสุขสมรวย วันทนียกุล         10              709
# 2     นายการันต์ ลุนพันธ์         11              712
# 3          นายไสว ผลาวงศ์         12              742
# 4        นายสงบ โสภิพันธ์         13              761
#
#                                            image_url  ...  percent_turn_out  \
# 0  https://cdn.ectreport.com/images/mp_candidates...  ...          72.60136
# ...

# %% [markdown]
# # เก็บข้อมูลเป็น csv

# %%
data_table_merge4.to_csv('merge_result_project1.csv', index=False)

# %%
data_table_cm.to_csv('merge_chiangmai_neww.csv', index=False)
